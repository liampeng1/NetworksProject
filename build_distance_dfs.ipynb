# %%
import geopy.distance
import pandas as pd
import numpy as np

# %%
routes_df = pd.read_csv('routes_df.csv')
IP_df = pd.read_csv('IP_df.csv')

# %%
IP_df.columns
# Out:
# Index(['IP', 'as', 'city', 'country', 'countryCode', 'isp', 'lat', 'lon',
#        'org', 'region', 'regionName', 'status', 'timezone', 'zip', 'message',
#        'asn'],
#       dtype='object')

# %%
# Calculate minimum estimates of distance traveled
# to be used as a minimum propogation delay

# %%
link_distances_df = pd.DataFrame(columns=['link_distance', 'coords', 'IPs'])
route_distances_df = pd.DataFrame()
for route_num, route in routes_df.groupby(['route_num']):
    coords_1 = None
    last_IP = 0
    route_distance = 0
    length = len(route)
    num_missed = 0
    for index, row in route.iterrows():
#         print (row)
        if row['IP'] == '???':
            num_missed += 1
            continue
        IP_row = IP_df.loc[IP_df['IP'] == row['IP']].iloc[0]
#         print (IP_row)
        if IP_row['status'] == 'fail':
            num_missed += 1
            continue
        coords_2 = (IP_row['lat'], IP_row['lon'])
#         print ('coords_1 : '+str(coords_1))
#         print ('coords_2 : '+str(coords_2))
#         print ("---")
        if coords_1 is None or coords_1 == coords_2:
            coords_1 = coords_2    
            continue
        coords = sorted([coords_1, coords_2])
        link_distance = 0
        if str(coords) in link_distances_df['coords']:
            link_distance = link_distances.loc[coords].iloc[0]
        else:
            link_distance = geopy.distance.distance(coords_1, coords_2).km
        route_distance += link_distance
        link_distance_dict = {'link_distance':link_distance, 'coords':str(coords)}
#         print (link_distance_dict)
        link_distances_df = link_distances_df.append(link_distance_dict, ignore_index=True)
        coords_1 = coords_2
    route_distance_dict = {'route_num':route_num, 'route_distance':route_distance, 'length':length, 'num_missed':num_missed}
#     print (route_distance_dict)
    route_distances_df = route_distances_df.append(route_distance_dict, ignore_index=True)

# %%
link_distances_df[:10]
# Out:
#    link_distance                                             coords  IPs
# 0    3908.468575        [(32.7405, -117.0935), (40.7234, -74.0054)]  NaN
# 1    3908.437847         [(32.7405, -117.0935), (40.7128, -74.006)]  NaN
# 2       5.514623           [(25.7617, -80.1918), (25.7975, -80.23)]  NaN
# 3    4114.157343  [(25.7617, -80.1918), (37.2414, -121.782999999...  NaN
# 4    2371.489087  [(32.7767, -96.79700000000001), (37.5272, -122...  NaN
# 5    1528.811423  [(37.5272, -122.26100000000001), (39.6004, -10...  NaN
# 6    4135.345541  [(37.5272, -122.26100000000001), (40.7234, -74...  NaN
# 7      52.897550  [(37.2414, -121.78299999999999), (37.5272, -12...  NaN
# 8    3875.612975  [(40.7128, -74.0059), (47.6062, -122.332000000...  NaN
# 9    3908.446296        [(32.7405, -117.0935), (40.7128, -74.0059)]  NaN

# %%
max(routes_df['route_num'])
# Out:
# 303

# %%
route_distances_df[:10]
# Out:
#    length  num_missed  route_distance  route_num
# 0    16.0        11.0        0.000000        1.0
# 1    14.0         9.0     7816.906422        2.0
# 2    15.0        10.0     4119.671965        3.0
# 3    11.0         4.0     3900.300510        4.0
# 4    14.0         9.0     4188.243091        5.0
# 5    14.0         9.0    11692.497118        6.0
# 6    14.0         9.0     4176.090469        7.0
# 7    15.0        11.0     4106.786224        8.0
# 8    16.0         4.0    22518.764435        9.0
# 9    18.0        10.0    14698.290697       10.0

# %%
route_distances_df['percentage_instact'] = route_distances_df.apply(lambda row : (row['length'] - row['num_missed']) / row['length'], axis=1)

# %%
route_distances_df['percentage_missing'] = (1 - route_distances_df['percentage_instact'])

# %%
route_distances_df[:10]
# Out:
#    length  num_missed  route_distance  route_num  percentage_instact  \
# 0    16.0        11.0        0.000000        1.0            0.312500
# 1    14.0         9.0     7816.906422        2.0            0.357143
# 2    15.0        10.0     4119.671965        3.0            0.333333
# 3    11.0         4.0     3900.300510        4.0            0.636364
# 4    14.0         9.0     4188.243091        5.0            0.357143
# 5    14.0         9.0    11692.497118        6.0            0.357143
# 6    14.0         9.0     4176.090469        7.0            0.357143
# 7    15.0        11.0     4106.786224        8.0            0.266667
# 8    16.0         4.0    22518.764435        9.0            0.750000
# 9    18.0        10.0    14698.290697       10.0            0.444444
#
#    percentage_missing
# 0            0.687500
# 1            0.642857
# 2            0.666667
# 3            0.363636
# 4            0.642857
# 5            0.642857
# 6            0.642857
# 7            0.733333
# 8            0.250000
# 9            0.555556

# %%
route_distances_df = route_distances_df.rename(columns={'percentage_missing':'percent_missing',
                                  'percentage_instact':'percent_complete',
                                    'route_distance':'route_distance(km)'})
route_distances_df[:10]
# Out:
#    length  num_missed  route_distance(km)  route_num  percent_complete  \
# 0    16.0        11.0            0.000000        1.0          0.312500
# 1    14.0         9.0         7816.906422        2.0          0.357143
# 2    15.0        10.0         4119.671965        3.0          0.333333
# 3    11.0         4.0         3900.300510        4.0          0.636364
# 4    14.0         9.0         4188.243091        5.0          0.357143
# 5    14.0         9.0        11692.497118        6.0          0.357143
# 6    14.0         9.0         4176.090469        7.0          0.357143
# 7    15.0        11.0         4106.786224        8.0          0.266667
# 8    16.0         4.0        22518.764435        9.0          0.750000
# 9    18.0        10.0        14698.290697       10.0          0.444444
#
#    percent_missing
# 0         0.687500
# 1         0.642857
# 2         0.666667
# 3         0.363636
# 4         0.642857
# 5         0.642857
# 6         0.642857
# 7         0.733333
# 8         0.250000
# 9         0.555556

# %%
len(route_distances_df)
# Out:
# 303

# %%
route_distances_df.loc[route_distances_df['percent_complete'] > 0.8]
# Out:
#      length  num_missed  route_distance(km)  route_num  percent_complete  \
# 14     20.0         1.0        12419.470639       15.0          0.950000
# 16     17.0         2.0        15120.282726       17.0          0.882353
# 17     19.0         0.0        15890.383019       18.0          1.000000
# 18      9.0         1.0        12956.788646       19.0          0.888889
# 19     14.0         2.0        31672.558432       20.0          0.857143
# 21     15.0         1.0        24711.825145       22.0          0.933333
# 23     16.0         1.0        27036.896299       24.0          0.937500
# 24     19.0         0.0        58234.033942       25.0          1.000000
# 25     20.0         3.0        24461.216497       26.0          0.850000
# 26     19.0         0.0        57152.992934       27.0          1.000000
# 27     18.0         3.0        34680.477234       28.0          0.833333
# 28     11.0         1.0        19046.859447       29.0          0.909091
# 29     10.0         1.0         2710.063383       30.0          0.900000
# 31      8.0         1.0         2274.603677       32.0          0.875000
# 32      9.0         1.0        11523.216987       33.0          0.888889
# 35     11.0         2.0        17319.925064       36.0          0.818182
# 37     12.0         1.0        30654.622862       38.0          0.916667
# 38     12.0         1.0        48030.664593       39.0          0.916667
# 40     10.0         0.0        30098.020881       41.0          1.000000
# 54     11.0         2.0        18042.282828       55.0          0.818182
# 66     20.0         3.0        47914.678816       67.0          0.850000
# 68     14.0         2.0        39525.430014       69.0          0.857143
# 71      7.0         1.0         3718.851813       72.0          0.857143
# 73      7.0         1.0         8152.741023       74.0          0.857143
# 74      7.0         1.0         7270.620484       75.0          0.857143
# 77      9.0         1.0        17376.085408       78.0          0.888889
# 79      9.0         1.0        18300.931942       80.0          0.888889
# 80      7.0         1.0        43041.741171       81.0          0.857143
# 82     12.0         1.0        23799.435530       83.0          0.916667
# 84     11.0         2.0        18935.432254       85.0          0.818182
# ..      ...         ...                 ...        ...               ...
# 191    10.0         1.0        18601.338858      192.0          0.900000
# 192     9.0         0.0         2626.542225      193.0          1.000000
# 194     6.0         0.0         6975.874099      195.0          1.000000
# 195     8.0         0.0        11862.980048      196.0          1.000000
# 198    10.0         1.0        17547.117005      199.0          0.900000
# 200    11.0         0.0        49862.877984      201.0          1.000000
# 201    11.0         0.0        47922.205813      202.0          1.000000
# 203     9.0         0.0        29834.926118      204.0          1.000000
# 219    11.0         2.0        29147.597745      220.0          0.818182
# 220    14.0         1.0        13665.359165      221.0          0.928571
# 222    12.0         2.0         9085.629129      223.0          0.833333
# 223     9.0         1.0        13962.846761      224.0          0.888889
# 226    11.0         1.0        21486.697196      227.0          0.909091
# 228    12.0         1.0        22411.543731      229.0          0.916667
# 229    10.0         1.0        50387.356578      230.0          0.900000
# 231     8.0         1.0        14883.856987      232.0          0.875000
# 233    11.0         1.0        19242.498627      234.0          0.909091
# 234    10.0         1.0         2975.331611      235.0          0.900000
# 236     8.0         1.0         2780.982052      237.0          0.875000
# 237     9.0         1.0        11913.312888      238.0          0.888889
# 240    11.0         2.0        17597.449845      241.0          0.818182
# 242    12.0         1.0        49838.693469      243.0          0.916667
# 243    12.0         2.0        48419.162761      244.0          0.833333
# 245    10.0         0.0        30293.660061      246.0          1.000000
# 247    20.0         3.0        24776.731202      248.0          0.850000
# 249    17.0         3.0        13252.557537      250.0          0.823529
# 250    12.0         1.0        15214.670316      251.0          0.916667
# 256    17.0         1.0        30790.277822      257.0          0.941176
# 257    18.0         1.0        57081.297270      258.0          0.944444
# 259    19.0         1.0        39611.934828      260.0          0.947368
#
#      percent_missing
# 14          0.050000
# 16          0.117647
# 17          0.000000
# 18          0.111111
# 19          0.142857
# 21          0.066667
# 23          0.062500
# 24          0.000000
# 25          0.150000
# 26          0.000000
# 27          0.166667
# 28          0.090909
# 29          0.100000
# 31          0.125000
# 32          0.111111
# 35          0.181818
# 37          0.083333
# 38          0.083333
# 40          0.000000
# 54          0.181818
# 66          0.150000
# 68          0.142857
# 71          0.142857
# 73          0.142857
# 74          0.142857
# 77          0.111111
# 79          0.111111
# 80          0.142857
# 82          0.083333
# 84          0.181818
# ..               ...
# 191         0.100000
# 192         0.000000
# 194         0.000000
# 195         0.000000
# 198         0.100000
# 200         0.000000
# 201         0.000000
# 203         0.000000
# 219         0.181818
# 220         0.071429
# 222         0.166667
# 223         0.111111
# 226         0.090909
# 228         0.083333
# 229         0.100000
# 231         0.125000
# 233         0.090909
# 234         0.100000
# 236         0.125000
# 237         0.111111
# 240         0.181818
# 242         0.083333
# 243         0.166667
# 245         0.000000
# 247         0.150000
# 249         0.176471
# 250         0.083333
# 256         0.058824
# 257         0.055556
# 259         0.052632
#
# [121 rows x 6 columns]

# %%
link_distances_df[:10]
# Out:
#    link_distance                                             coords  IPs
# 0    3908.468575        [(32.7405, -117.0935), (40.7234, -74.0054)]  NaN
# 1    3908.437847         [(32.7405, -117.0935), (40.7128, -74.006)]  NaN
# 2       5.514623           [(25.7617, -80.1918), (25.7975, -80.23)]  NaN
# 3    4114.157343  [(25.7617, -80.1918), (37.2414, -121.782999999...  NaN
# 4    2371.489087  [(32.7767, -96.79700000000001), (37.5272, -122...  NaN
# 5    1528.811423  [(37.5272, -122.26100000000001), (39.6004, -10...  NaN
# 6    4135.345541  [(37.5272, -122.26100000000001), (40.7234, -74...  NaN
# 7      52.897550  [(37.2414, -121.78299999999999), (37.5272, -12...  NaN
# 8    3875.612975  [(40.7128, -74.0059), (47.6062, -122.332000000...  NaN
# 9    3908.446296        [(32.7405, -117.0935), (40.7128, -74.0059)]  NaN

# %%
link_distances_df = link_distances_df.loc[link_distances_df['link_distance'] > 0]

# %%
len(link_distances_df)
# Out:
# 1790

# %%
len(route_distances_df.loc[route_distances_df['percent_complete'] == 1])
# Out:
# 16

# %%
routes_df.columns
# Out:
# Index(['IP', 'Loss', 'Snt', 'Last', 'Avg', 'Best', 'Wrst', 'StDev', 'time',
#        'order', 'route_num'],
#       dtype='object')

# %%
def get_end_latency(row):
    route_row = routes_df.loc[(routes_df['order'] == row['length'] - 1) & 
                              (routes_df['route_num'] == row['route_num'])].iloc[0]
    return route_row['Avg']

# %%
route_distances_df['end_latency'] = route_distances_df.apply(get_end_latency, axis=1)

# %%
len(route_distances_df.loc[(route_distances_df['end_latency'] > 0)])
# Out:
# 136

# %%
len(route_distances_df.loc[(route_distances_df['end_latency'] > 0) &
                    (route_distances_df['percent_complete'] >= .8)])
# Out:
# 70

# %%
def get_birds_eye_distance(row):
    start_row = routes_df.loc[(routes_df['order'] == 1) & 
                              (routes_df['route_num'] == row['route_num'])].iloc[0]
    end_row = routes_df.loc[(routes_df['order'] == row['length'] - 1) & 
                              (routes_df['route_num'] == row['route_num'])].iloc[0]
    if start_row['IP'] == '???' or end_row['IP'] == '???':
        return -1
    IP_start_row = IP_df.loc[IP_df['IP'] == start_row['IP']].iloc[0]
    IP_end_row = IP_df.loc[IP_df['IP'] == end_row['IP']].iloc[0]
    if IP_start_row['status'] == 'fail' or IP_end_row['status'] == 'fail':
        return -1
    coords_1 = (IP_start_row['lat'], IP_start_row['lon'])
    coords_2 = (IP_end_row['lat'], IP_end_row['lon'])
    distance = geopy.distance.distance(coords_1, coords_2).km
    return distance

# %%
route_distances_df['birds_eye_distance(km)'] = route_distances_df.apply(get_birds_eye_distance, axis=1)

# %%
len(route_distances_df.loc[(route_distances_df['birds_eye_distance(km)'] > 0) &
                    (route_distances_df['percent_complete'] >= 0.8)])
# Out:
# 66

# %%
link_distances_df.to_csv('link_distances_df.csv', index=False)

# %%
route_distances_df.to_csv('route_distances_df.csv', index=False)

# %%
len(routes_df.loc[(routes_df['order'] == 0) &
                   (routes_df['IP'] != '???')])
# Out:
# 173
